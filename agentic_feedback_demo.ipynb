# %% [markdown]
# # Agentic Feedback Loop Demo
#
# This notebook demonstrates how to use the placeholder agentic framework to run a codec detection → LLM perturbation → verification loop on a single audio file. Replace the stub components with real services when they become available.

# %%
from pathlib import Path

from agentic_feedback import FeedbackOrchestrator

# Replace this path with any adversarial or compressed audio you want to test.
audio_sample = Path("/Users/kunal/Downloads/adversarial_dataset-A/Adversarial-Examples/short-signals/adv-short-target/adv-short2short-000303.wav")

orchestrator = FeedbackOrchestrator()
summary = orchestrator.run_feedback_loop(audio_sample, max_iterations=3)

summary.to_dict()
